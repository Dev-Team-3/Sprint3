# %%
import pandas as pd 
import numpy as np
df=pd.read_csv("Sprint.csv",sep=";") 
df
# Out:
#           Type      Products Price  Quantity
# 0        Chips         Simba    R6      10.0
# 1          NaN          Lays    R7      10.0
# 2          NaN      Pringles   R18      15.0
# 3          NaN       Doritos    R8      25.0
# 4          NaN       NikNaks    R4      50.0
# 5          NaN           NaN   NaN       NaN
# 6   Cooldrinks          Coke   R12      50.0
# 7          NaN        Fanta    R12      40.0
# 8          NaN          Jive    R7      25.0
# 9          NaN       Monster   R20      10.0
# 10         NaN        Sprite   R12      50.0
# 11         NaN           NaN   NaN       NaN
# 12   Chocolate       Cadbury    R8      20.0
# 13         NaN           Tex    R9      15.0
# 14         NaN           P.S    R5      30.0
# 15         NaN       Bar One    R8      30.0
# 16         NaN       Snikers   R10      28.0
# 17         NaN           NaN   NaN       NaN
# 18        Pies  Pepper Steak   R15      35.0
# 19         NaN       Chicken   R15      35.0
# ...

# %%
data = np.array(['Type','Products','Price','Quantity']) 
s = pd.Series(data) 
s
# Out:
# 0        Type
# 1    Products
# 2       Price
# 3    Quantity
# dtype: object

# %%
df = pd.read_csv("Sprint.csv",sep=";") 
df.filter(["Quantity", "Type"])
# Out:
#     Quantity        Type
# 0       10.0       Chips
# 1       10.0         NaN
# 2       15.0         NaN
# 3       25.0         NaN
# 4       50.0         NaN
# 5        NaN         NaN
# 6       50.0  Cooldrinks
# 7       40.0         NaN
# 8       25.0         NaN
# 9       10.0         NaN
# 10      50.0         NaN
# 11       NaN         NaN
# 12      20.0   Chocolate
# 13      15.0         NaN
# 14      30.0         NaN
# 15      30.0         NaN
# 16      28.0         NaN
# 17       NaN         NaN
# 18      35.0        Pies
# 19      35.0         NaN
# 20      25.0         NaN
# 21      30.0         NaN
# 22      30.0         NaN
# 23       NaN         NaN
# 24      50.0       Fruit
# 25      50.0         NaN
# 26      20.0         NaN
# 27     100.0         NaN
# 28      60.0         NaN
# 29       NaN         NaN
# 30      20.0    Cupcakes
# 31      25.0         NaN
# 32      15.0         NaN
# 33      10.0         NaN
# 34      20.0         NaN
# 35       NaN         NaN
# ...

# %%
data = [['Simba',10],['Lays',10],['Pringles',15], ['Doritos', 25], ['NikNaks', 50]] 
df = pd.DataFrame(data,columns=['Chips','Quantity']) 
df
# Out:
#       Chips  Quantity
# 0     Simba        10
# 1      Lays        10
# 2  Pringles        15
# 3   Doritos        25
# 4   NikNaks        50

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
  
df = pd.DataFrame(np.random.rand(10, 5),  
      columns =['Simba', 'Lays', 'Pringles', 'Doritos', 'NikNaks']) 
  
df.plot.box() 
plt.show()
